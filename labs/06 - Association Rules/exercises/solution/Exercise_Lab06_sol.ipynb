# %% [markdown]
# ## Exercise
#
# Let's try with a more real and bigger dataset. Load the `Groceries.csv` file and try to find association rules Using the __confidence__ metric. Use a support threshold of __0.01__ and confidence threshold of __0.1__.

# %% [markdown]
# ### Load the data
# First, load the `Groceries.csv` file from the GitHub repository. Since this is not a proper csv file and there are different number of values in each row, you have to read the file manually. Run the code cell below to read the file and save it as a list of lists.

# %%
# We need the requests package to read the data from url.
import requests
response = requests.get("https://media.githubusercontent.com/media/michalis0/Business-Intelligence-and-Analytics/master/data/Groceries.csv")
data = response.text

dataset = []
for line in data.split("\n"):
    transaction = []
    row = line.rstrip().split(",")
    for item in row:
        transaction.append(item)
    dataset.append(transaction)

# %% [markdown]
# Next, create the one-hot encoded dataframe with `TransactionEncoder()`.

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# /Users/aajalloe/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# create the one_hot encoded dataframe with TransactionEncoder()
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head()
# Out:
# /Users/aajalloe/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0  False                  False     False             False             False
# 1  False                  False     False             False             False
# 2  False                  False     False             False             False
# 3  False                  False     False             False             False
# 4  False                  False     False             False             False
#
#    baby cosmetics  baby food   bags  baking powder  bathroom cleaner  ...  \
# 0           False      False  False          False             False  ...
# 1           False      False  False          False             False  ...
# 2           False      False  False          False             False  ...
# 3           False      False  False          False             False  ...
# 4           False      False  False          False             False  ...
#
#    turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0   False    False    False               False   False        False
# 1   False    False    False               False   False        False
# 2   False    False    False               False   False        False
# 3   False    False    False               False   False        False
# 4   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False       False   False     False
# 1       False       False    True     False
# 2       False        True   False     False
# 3       False       False    True     False
# 4       False        True   False     False
#
# [5 rows x 170 columns]

# %% [markdown]
# Then find the frequexnt itemsets with `min_support=0.01` and `max_len=2`.
#
# Then find the association rules with `metric='confidence'` and `min_threshold=0.1`.

# %%
# find the frequent itemsets with  min_support=0.01, max_len=2
freq_items = apriori(df, min_support=0.01, use_colnames=True, max_len=2)

# find the association rules with metric='confidence' and min_threshold=0.1

rules = association_rules(freq_items, metric="confidence", min_threshold=0.1)
# Out:
# /Users/aajalloe/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Check out the rules you have found that have "bottled beer" as antecedant. Are all of these rules interesting?
#
# __Important: This exercise answers the Moodle quiz question 1.__

# %%
# extract rules with 'bottled beer' as antecedents
rules[rules["antecedents"].astype(str).str.contains("bottled beer")].sort_values(by="lift", ascending=False)
# Out:
# /Users/aajalloe/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        antecedents         consequents  antecedent support  \
# 10  (bottled beer)     (bottled water)            0.080521
# 14  (bottled beer)              (soda)            0.080521
# 12  (bottled beer)  (other vegetables)            0.080521
# 15  (bottled beer)        (whole milk)            0.080521
# 13  (bottled beer)        (rolls/buns)            0.080521
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 10            0.110512  0.015758    0.195707  1.770906  0.006860    1.105925
# 14            0.174359  0.016978    0.210859  1.209332  0.002939    1.046252
# 12            0.193473  0.016165    0.200758  1.037652  0.000587    1.009114
# 15            0.255490  0.020435    0.253788  0.993338 -0.000137    0.997719
# 13            0.183916  0.013623    0.169192  0.919940 -0.001186    0.982277
#
#     zhangs_metric
# 10       0.473439
# 14       0.188256
# 12       0.039463
# 15      -0.007242
# 13      -0.086465

# %% [markdown]
# Check out the rules you have found that have "domestic eggs" as antecedant. Are all of these rules interesting?
#
# __Important: This exercise answers the Moodle quiz question 2.__

# %%
# extract rules with 'domestic eggs' as antecedents
rules[rules["antecedents"].astype(str).str.contains("domestic eggs")].sort_values(by="confidence", ascending=False)
# Out:
# /Users/aajalloe/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          antecedents         consequents  antecedent support  \
# 125  (domestic eggs)        (whole milk)             0.06344
# 116  (domestic eggs)  (other vegetables)             0.06344
# 118  (domestic eggs)        (rolls/buns)             0.06344
# 120  (domestic eggs)   (root vegetables)             0.06344
# 126  (domestic eggs)            (yogurt)             0.06344
# 121  (domestic eggs)              (soda)             0.06344
# 122  (domestic eggs)    (tropical fruit)             0.06344
# 77   (domestic eggs)      (citrus fruit)             0.06344
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 125            0.255490  0.029992    0.472756  1.850391  0.013783    1.412080
# 116            0.193473  0.022265    0.350962  1.814008  0.009991    1.242649
# 118            0.183916  0.015657    0.246795  1.341887  0.003989    1.083481
# 120            0.108987  0.014335    0.225962  2.073281  0.007421    1.151122
# 126            0.139488  0.014335    0.225962  1.619940  0.005486    1.111718
# 121            0.174359  0.012403    0.195513  1.121320  0.001342    1.026294
# 122            0.104921  0.011387    0.179487  1.710694  0.004731    1.090878
# 77             0.082757  0.010370    0.163462  1.975194  0.005120    1.096474
#
#      zhangs_metric
# 125       0.490704
# 116       0.479131
# 118       0.272039
# 120       0.552739
# 126       0.408616
# 121       0.115523
# 122       0.443583
# 77        0.527164
