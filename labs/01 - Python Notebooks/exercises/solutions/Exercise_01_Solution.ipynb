# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/michalis0/Business-Intelligence-and-Analytics/blob/master/labs/01%20-%20Python%20Notebooks/exercises/solutions/Exercise_01_Solution.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Exercise: Some simple Statistics tasks
#
# **Table of Contents**
#
# 1. Arithmetic Mean
# 2. Mean Squared Error
#
#     A. Bias of an estimator <br>
#     B. Variance of an estimator

# %% [markdown]
# ## 1. The Arithmetic Mean

# %% [markdown]
# $$ Mean(x) = \frac{1}{n} * \sum_{i=1}^{n} x_i$$

# %% [markdown]
# Embedded a formatted code block:
#
# ```python
# x=[1,3,9,4]
# x_bar=1/4*sum(x)
# ```

# %%
# actual python calculation
x=[1,3,9,4]
x_bar=1/len(x)*sum(x)
x_bar
# Out:
# 4.25

# %% [markdown]
# ## 2. Mean Squared Error
#
# $$ MSE(x) = bias^2(x) + var^2(x) $$
#
# For further information see [http://www.statisticshowto.com/mean-squared-error](http://www.statisticshowto.com/mean-squared-error)
